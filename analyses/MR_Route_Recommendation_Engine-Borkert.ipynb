# %%
import numpy as np
import pandas as pd
import os
import gzip
import dill
from os.path import exists as file_exists
import geopandas
from gpx_converter import Converter
from shapely.geometry import LineString, MultiPoint, Point
from shapely.ops import split

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.impute import SimpleImputer
from sklearn.neighbors import NearestNeighbors
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer, RobustScaler, OneHotEncoder

# %%
from spacy.lang.en.stop_words import STOP_WORDS
STOP_WORDS = STOP_WORDS.union({'ll', 've', 'pron'})

# %%
from sklearn import set_config
set_config(display='diagram')
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# # Motorcycle Road Recommendation Engine

# %% [markdown]
# ## Data input

# %%
# calculates the sinuosity of each route from its gpx file of lat/lon coordinates
def calcluate_sinuosity(gpx_file_num):
    gpx_file = f'../gpx_files/{str(gpx_file_num)}.gpx'
    if file_exists(gpx_file):
        try:
            gpx_array = Converter(input_file=gpx_file).gpx_to_numpy_array()
        except Exception:
            return -1
        
        splits = 4
        subsets = np.array_split(gpx_array, splits)
        subset_sinuosities = []
        
        for subset in subsets:
            start_pt = subset[0]
            end_pt = subset[-1]
            route = LineString(subset)
            route_SL = LineString((start_pt, end_pt))
            route_sinuosity = route.length / route_SL.length
            subset_sinuosities.append(route_sinuosity)
        return sum(subset_sinuosities)/splits
    else:
        return -2

def get_route_coords(gpx_file_num):
    gpx_file = f'../gpx_files/{str(gpx_file_num)}.gpx'
    if file_exists(gpx_file):
        try:
            gpx_df = Converter(input_file=gpx_file).gpx_to_dataframe()
#             return gpx_df
            route_line = LineString(list(zip(gpx_df.longitude, gpx_df.latitude)))
            return route_line
        except Exception:
            return None

valid_states = ['Alabama', 'California', 'Georgia', 'Missouri', 'Illinois', 'Ohio',
       'Kentucky', 'Colorado', 'United States', 'Indiana', 'New York',
       'Vermont', 'Texas', 'Florida', 'Minnesota', 'Virginia',
       'Oklahoma', 'Arkansas', 'Maryland', 'West Virginia',
       'Michigan', 'North Carolina', 'Oregon', 'Pennsylvania',
       'Washington', 'New Jersey', 'Alaska',
       'South Carolina', 'Utah', 'New Hampshire', 'Iowa', 'Louisiana',
       'Mississippi', 'Wisconsin',
       'South Dakota', 'Wyoming', 'Massachusetts', 'New Mexico',
       'Montana', 'Idaho', 'Nevada', 'Arizona',
       'Kansas', 'Northeast', 'Southwest', 'Golf Coast', 'Southeast',
       'Tennessee', 'Nebraska', 'Delaware', 'Pacific Coast',
       'Appalachian Mountains', 'Maine', 'Rhode Island', 'Connecticut',
       'North Dakota', 'Hawaii']

from math import radians, cos, sin, asin, sqrt

# Calculates distance between 2 GPS coordinates
def haversine(lat1, lon1, lat2, lon2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 3956 # Radius of earth in kilometers. Use 3956 for miles
    return c * r

# %%
#read in data
df_raw = pd.read_csv('../data/route_data2.csv')#.drop('files',axis=1)
df_raw['state_prop_rank'] = df_raw.state_rank / df_raw.num_state_routes
df_raw['sinuosity'] = [calcluate_sinuosity(x) for x in df_raw['gpx_file_num']]
df = df_raw.loc[df_raw.sinuosity>=0].reset_index(drop=True)

# %%
route_coords = {
    'gpx_file_num': [x for x in df['gpx_file_num']],
    'geometry': [get_route_coords(x) for x in df['gpx_file_num']]
}

route_gdf = geopandas.GeoDataFrame(route_coords, crs='EPSG:2163')
# route_gdf['user_rating'] = df.user_rating
# route_gdf['route_name'] = df.name
# route_gdf['state'] = df.state

# %%
route_gdf
# Out:
#       gpx_file_num                                           geometry
# 0             6652  LINESTRING (-86.330 34.681, -86.330 34.683, -8...
# 1            34749  LINESTRING (-86.329 34.664, -86.329 34.664, -8...
# 2            34750  LINESTRING (-86.632 32.840, -86.629 32.836, -8...
# 3            34751  LINESTRING (-87.895 34.879, -87.895 34.879, -8...
# 4            34752  LINESTRING (-86.826 33.521, -86.826 33.518, -8...
# ...            ...                                                ...
# 2043         67128  LINESTRING (-120.389 35.656, -120.394 35.656, ...
# 2044         67147  LINESTRING (-100.765 34.103, -100.766 34.113, ...
# 2045         67232  LINESTRING (-122.873 38.608, -122.874 38.609, ...
# 2046         67234  LINESTRING (-122.515 37.945, -122.514 37.945, ...
# 2047         67262  LINESTRING (-83.028 39.968, -83.029 39.967, -8...
#
# [2048 rows x 2 columns]

# %%
#length of route in miles
distances = []
for line in route_gdf.geometry:
    numCoords = len(line.coords) - 1
    distance = 0
    for i in range(0, numCoords):
        point1 = line.coords[i]
        point2 = line.coords[i + 1]
        distance += haversine(point1[0], point1[1], point2[0], point2[1])
    distances.append(distance)
df['route_length'] = distances

# %%
#representative point for each route
rep_point = route_gdf.geometry.centroid
route_gdf['rep_point'] = rep_point
df['loc_lat'] = rep_point.y
df['loc_lon'] = rep_point.x

# %%
df.head()
# Out:
#    gpx_file_num                                       name          state  \
# 0          6652                     Paint Rock Valley Loop  United States
# 1         34749                          Paint Rock Valley        Alabama
# 2         34750  Central Alabama Country Tour - Highway 22        Alabama
# 3         34751                             County Road 14      Tennessee
# 4         34752       Alabama's "Mini-Dragon" to 29 Dreams        Alabama
#
#    route_length  user_rating  num_user_reviews  num_users_rode  \
# 0     39.727942         0.00                 0               0
# 1     23.627018         4.00                 6               6
# 2     87.583394         3.50                 3               6
# 3     18.317190         0.00                 0               3
# 4     27.065368         2.33                 9              11
#
#    num_users_want2ride  scenery_rating  drive_enjoyment_rating  ...  author  \
# 0                    0               3                       2  ...   admin
# 1                    3               5                       4  ...     NaN
# 2                    3               4                       4  ...     NaN
# 3                    0               4                       3  ...     NaN
# 4                    6               4                       5  ...     NaN
#
#    author_points                                scenery_description  \
# 0            109  The valley road winds beside the Paint Rock Ri...
# 1              0  The valley road winds beside the Paint Rock Ri...
# 2              0  Drive through a nice slide of Central Alabama ...
# 3              0  County Rd 14 west of the Natchez Trace runs al...
# 4              0  On this route you will find several homes and ...
#
#                          drive_enjoyment_description  \
# 0  Basically good asphalt...occasional fault here...
# 1  Basically good asphalt...occasional fault here...
# 2  Smooth asphalt the entire way. Maybe one or tw...
# 3  Road quality is fair, though I remember the Al...
# 4  The road is nicely paved and marked and has nu...
#
#                                  tourism_description files state_prop_rank  \
# 0  Not much to do...just lots of outdoors to see....   NaN        0.625000
# 1  Not much to do...just lots of outdoors to see....   NaN        0.461538
# 2  Only an occasional store along the way. Roanok...   NaN        0.538462
# 3  Really not much to do off the bike ... Waterlo...   NaN        0.888889
# 4  Upon getting to the Leeds exit from interstate...   NaN        0.576923
#
#   sinuosity    loc_lat    loc_lon
# 0  1.429574  34.726485 -86.198479
# 1  1.137782  34.770065 -86.189154
# 2  1.134919  32.949980 -85.993627
# 3  1.155947  34.961208 -88.036771
# 4  1.581907  33.529228 -86.651468
#
# [5 rows x 23 columns]

# %%
route_gdf = route_gdf.merge(df, on='gpx_file_num').drop('files',axis=1)

# %%
route_gdf.route_length.min()
# Out:
# 0.8788460902607798

# %%
# # Write files
# with gzip.open('../data/route_gdf.pkl', 'wb') as f:
#         dill.dump(route_gdf, f)
# with gzip.open('../data/route_df.pkl', 'wb') as f:
#         dill.dump(df, f)

# Read files
with gzip.open('../data/route_gdf.pkl', 'rb') as f:
    route_gdf = dill.load(f)
with gzip.open('../data/route_df.pkl', 'rb') as f:
    df = dill.load(f)

# %% [markdown]
# # Feature processing

# %%
# functions for transformers
def calc_row_sum(cols):
    return pd.DataFrame(cols.apply(lambda x: x.sum(), axis=1))

# %%
numeric_features = ['route_length','state_prop_rank']#,'scenery_rating','drive_enjoyment_rating','tourism_rating']

numeric_transformer = Pipeline(
    steps=[("imputer", SimpleImputer(strategy="mean")), ("scaler", RobustScaler())]
)

#tfidf vectorizer for each route's descriptions
description_transformer = TfidfVectorizer(stop_words=STOP_WORDS, 
#                                    ngram_range=(1,2),
                                   min_df=.01
                                  )

# Route 'engagement' by MR site users: 
# num_user_reviews + num_users_rode + num_users_want2ride
engagement_transformer = FunctionTransformer(calc_row_sum)


preprocessor = ColumnTransformer([
    ('route_engagement',engagement_transformer, ['num_user_reviews','num_users_rode','num_users_want2ride']), 
#     ('scenery', description_transformer, 'scenery_description'),
#     ('drive_enjoyment', description_transformer, 'drive_enjoyment_description'),
#     ('tourism', description_transformer, 'tourism_description'),
    ('state', OneHotEncoder(handle_unknown='ignore'), ['state']),
    ('numeric_features',numeric_transformer, numeric_features),
#     ('locale','passthrough',['loc_lat','loc_lon'])
])

features = preprocessor.fit_transform(df)

# %%
features
# Out:
# <2048x73 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8040 stored elements in Compressed Sparse Row format>

# %%
engine_pipe = Pipeline([
    ('preprocessor', preprocessor),#preprocessor to deal to transform/generate each feature
    ('nn', NearestNeighbors(n_neighbors=20)),#Nearest Neighbors
])

engine_pipe.fit(df)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('route_engagement',
#                                                   FunctionTransformer(func=<function calc_row_sum at 0x7fca9f426430>),
#                                                   ['num_user_reviews',
#                                                    'num_users_rode',
#                                                    'num_users_want2ride']),
#                                                  ('state',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['state']),
#                                                  ('numeric_features',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['route_length',
#                                                    'state_prop_rank'])])),
#                 ('nn', NearestNeighbors(n_neighbors=20))])

# %% [markdown]
# ## Model Exploration

# %% [markdown]
# A few roads I've been on (to test functionality):

# %%
df.iloc[[37,53]]
df[df.gpx_file_num == 35762]
# Out:
#      gpx_file_num                   name       state  route_length  \
# 989         35762  The Panoramic Highway  California      7.916804
#
#      user_rating  num_user_reviews  num_users_rode  num_users_want2ride  \
# 989          4.5                 2              18                    6
#
#      scenery_rating  drive_enjoyment_rating  ...         author  \
# 989               5                       3  ...  silverwinggli
#
#      author_points                                scenery_description  \
# 989              5  If you like twistys and Amazing mountain views...
#
#                            drive_enjoyment_description  \
# 989  Road is generally good.  It is a narrow mounta...
#
#                                    tourism_description files state_prop_rank  \
# 989  There is a small town along the way, but for a...   NaN        0.481752
#
#     sinuosity    loc_lat     loc_lon
# 989  1.486539  37.901778 -122.595512
#
# [1 rows x 23 columns]

# %%
n=989

dists, indices = engine_pipe[1].kneighbors(features[n])
df.iloc[indices[0]]
# Out:
#       gpx_file_num                                     name           state  \
# 989          35762                    The Panoramic Highway      California
# 1121         35894     Las Flores Canyon Road to Piuma Road      California
# 869          35638      Through Death Valley on Badwater Rd      California
# 1318         36094    The Cuyahoga Valley National Park Run            Ohio
# 672          35432                       The St Croix Trail       Minnesota
# 757          35522                    Kickapoo river valley       Wisconsin
# 745          35510     The Highland Scenic Highway (SR 150)   West Virginia
# 4            34752     Alabama's "Mini-Dragon" to 29 Dreams         Alabama
# 128          34878                Starved Rock Run on Rt 71        Illinois
# 909          35680                         Up to the Ridges  North Carolina
# 1010         35783                     Back roads of Morris        Illinois
# 504          35260                     The Logan Canyon Run            Utah
# 1230         36004                          Taos to Mora NM      New Mexico
# 294          35049                          Red Rock Ramble          Nevada
# 107          34857  Sugarloaf Mountain - The North Approach         Florida
# 731          35495         From Paris and Havana on the 309        Arkansas
# 372          35127                    East Ohio Border Tour            Ohio
# 1189         35963                     Guadalupe River Road           Texas
# 753          35518                         Seneca Lake Loop            Ohio
# 824          35592                The Wind River Canyon Run         Wyoming
#
#       route_length  user_rating  num_user_reviews  num_users_rode  \
# 989       7.916804         4.50                 2              18
# 1121     14.987478         4.50                 3              17
# 869      60.681495         4.80                 5              15
# 1318     15.484292         3.20                 5              15
# 672       7.525871         3.67                 6              10
# 757      18.489999         4.00                 6              19
# 745      23.153531         4.75                 4              15
# 4        27.065368         2.33                 9              11
# 128      12.150456         4.20                 7               8
# 909      38.035487         4.50                 2              18
# 1010     28.617712         3.89                 9              10
# 504      36.562004         4.29                 9               9
# 1230     38.992737         4.80                10               5
# 294      15.442195         3.20                 7               8
# 107      19.499664         4.00                 5              13
# 731      24.029767         4.20                 5               5
# 372      17.692876         4.25                 9              13
# 1189      8.609495         4.25                 5              16
# 753      18.778736         3.50                 2              18
# 824      18.767596         4.75                 8               8
#
#       num_users_want2ride  scenery_rating  drive_enjoyment_rating  ...  \
# 989                     6               5                       3  ...
# 1121                    6               4                       4  ...
# 869                     6               4                       4  ...
# 1318                    6               5                       4  ...
# 672                    10               5                       4  ...
# 757                     1               4                       4  ...
# 745                     7               5                       5  ...
# 4                       6               4                       5  ...
# 128                    11               5                       4  ...
# 909                     6               5                       4  ...
# 1010                    7               4                       3  ...
# 504                     8               5                       5  ...
# 1230                   11               5                       4  ...
# 294                    10               5                       3  ...
# 107                     7               4                       3  ...
# 731                    15               5                       3  ...
# 372                     5               5                       5  ...
# 1189                    6               4                       5  ...
# 753                     7               5                       5  ...
# 824                     9               5                       4  ...
#
#                   author  author_points  \
# 989        silverwinggli              5
# 1121            adhersin             11
# 869             steben53             15
# 1318        Voodoo Daddy              6
# 672      MCR Contributor           1038
# 757              jhlemay              5
# 745                Pouge             62
# 4                    NaN              0
# 128                  NaN              0
# 909       outdoorchild92              5
# 1010               Dingo              5
# 504                  NaN              0
# 1230          wadenelson             49
# 294                  NaN              0
# 107                  NaN              0
# 731            donniejoe             47
# 372                  NaN              0
# 1189  2011flhx.roadslayr             10
# 753             Colt2Cat              7
# 824         Raider Rider              7
#
#                                     scenery_description  \
# 989   If you like twistys and Amazing mountain views...
# 1121  Gorgeous view on the Valley and the ocean. You...
# 869   I need to give this 4 stars because it's so mu...
# 1318  The route begins riding down into a somewhat i...
# 672   You can see the St. Croix river bluff, some pr...
# 757   This route crosses the Kickapoo River at least...
# 745   A beautiful ride through the highlands of W.Va...
# 4     On this route you will find several homes and ...
# 128   The area is relatively very hilly for Illinois...
# 909   The road goes through Cherokee and Pisgah nati...
# 1010  This route will take you west from the southwe...
# 504   Scenic ride through the canyon with great view...
# 1230  Rivers, mountains, fields, just a beautiful ri...
# 294   Located about 20 miles outside of Vegas, this ...
# 107   Scenic views and winding twisties and S curves...
# 731   This ride includes Mount Magazine State Park, ...
# 372   Take a scenic joyride thru the woods, and mayb...
# 1189  This route sweeps back and forth along the Gua...
# 753   This loop provides several different views of ...
# 824   An exciting ride for those who enjoy traversin...
#
#                             drive_enjoyment_description  \
# 989   Road is generally good.  It is a narrow mounta...
# 1121  Very few bumps/holes. And the road surfaces of...
# 869   The road starts out with some straight section...
# 1318  The roads are mostly newly paved 2 lane street...
# 672   The route is fun, full of S curves going up an...
# 757   The main road is great, well paved and maintai...
# 745   Very smooth road. Much of the roads in the sur...
# 4     The road is nicely paved and marked and has nu...
# 128   Nicely paved, some areas are narrow for a two ...
# 909   Many mountain curves and good climbs here and ...
# 1010  For the most part, the road is in good conditi...
# 504   Challenging curves open meadows and mountain t...
# 1230  I haven't ridden this in awhile and can't comm...
# 294   Short and sweet; this route's only real limita...
# 107   Roads are fair, with occasional dirt or sand o...
# 731   The road surface qualities are average.  There...
# 372   Top notch pavement. This road can be ridden as...
# 1189  You will find both gentle sweeping and sharp t...
# 753   Many, many curves and hills provide a very sat...
# 824   The road is well maintained with plenty of twi...
#
#                                     tourism_description files state_prop_rank  \
# 989   There is a small town along the way, but for a...   NaN        0.481752
# 1121  Don't expect to find any stores on the way. Yo...   NaN        0.510949
# 869   For this stretch of road amenities are non-exi...   NaN        0.291971
# 1318  The ride is about 26 miles long but can easily...   NaN        0.390000
# 672   Stillwater is a hot spot for shopping, restaur...   NaN        0.357143
# 757   Highlight of the road is the visitor center wh...   NaN        0.313725
# 745   Marlinton has food, gas and hotels. Marlinton ...   NaN        0.354167
# 4     Upon getting to the Leeds exit from interstate...   NaN        0.576923
# 128   Starved Rock State Park has a nice lodge, camp...   NaN        0.200000
# 909   There are maybe one or two restaurants and a m...   NaN        0.567308
# 1010  Plenty of gas along the way in Morris and Sene...   NaN        0.180000
# 504   Few amenities only camping and picnic areas al...   NaN        0.250000
# 1230  No amenities outside of Taos, Angel Fire or Mora.   NaN        0.115385
# 294   It is all nature stuff so if your looking for ...   NaN        0.571429
# 107   Great food at RalphJanes Country Kitchen on Rt...   NaN        0.442308
# 731   There is a full service restaurant, lodge, cam...   NaN        0.472727
# 372   This road will pass thru a few towns along the...   NaN        0.340000
# 1189  Off-season riding is definitely recommended as...   NaN        0.284483
# 753   Seneca Lake Park has two campgrounds, one at t...   NaN        0.690000
# 824   You'll be able to refuel in both Shoshoni and ...   NaN        0.272727
#
#      sinuosity    loc_lat     loc_lon
# 989   1.486539  37.901778 -122.595512
# 1121  2.235005  34.082005 -118.678348
# 869   1.209418  36.086650 -116.661496
# 1318  1.217880  41.243634  -81.572821
# 672   1.095682  44.903679  -92.791397
# 757   1.229419  43.765554  -90.552692
# 745   1.392550  38.259878  -80.207685
# 4     1.581907  33.529228  -86.651468
# 128   1.201002  41.317982  -88.935659
# 909   1.374555  36.278032  -81.938544
# 1010  1.124174  41.391296  -88.375515
# 504   1.357409  41.851997 -111.596322
# 1230  1.453764  36.261597 -105.318234
# 294   1.141697  36.101797 -115.405665
# 107   1.256549  28.733194  -81.637229
# 731   2.350861  35.198918  -93.621770
# 372   1.258916  40.847260  -80.555741
# 1189  1.392745  29.788681  -98.155189
# 753   1.604114  39.906494  -81.395494
# 824   1.194751  43.439047 -108.162130
#
# [20 rows x 23 columns]
